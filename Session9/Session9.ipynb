# %% [markdown]
# Session 15
# ========================
# Goal 1
#
# Create a lazy iterator that will return a named tuple of the data in each row. The data types should be appropriate - i.e. if the column is a date, you should be storing dates in the named tuple, if the field is an integer, then it should be stored as an integer, etc.
#
# Goal 2
#
# Calculate the number of violations by car make.
#
# Note:
# Try to use lazy evaluation as much as possible - it may not always be possible though! That's OK, as long as it's kept to a minimum

# %%
from pathlib import Path

# %%
path = Path('./')

# %%
from collections import namedtuple
from datetime import datetime

# %%
def cast(data_type, value):
    if data_type == 'INT':
        return int(value)
    elif data_type == 'DATE':
        return datetime.strptime(value, '%m/%d/%Y')
    else:
        return str(value)

# %%
def cast_row(data_types, data_row):
    return [cast(data_type, value) 
            for data_type, value in zip(data_types, data_row)]

# %%
#Goal1
file = open('nyc_parking_tickets_extract-1.csv') 
file_iter = iter(file)
headers = next(file_iter).strip('\n').replace(' ','').split(',')
print(headers)
CarParking = namedtuple('CarParking',headers)
data_types = ['INT','STRING','STRING','STRING','DATE','INT','STRING','STRING','STRING']
cars = (CarParking(*cast_row(data_types, 
                          line.strip('\n').split(',')))
            for line in file_iter)
# Out:
# ['SummonsNumber', 'PlateID', 'RegistrationState', 'PlateType', 'IssueDate', 'ViolationCode', 'VehicleBodyType', 'VehicleMake', 'ViolationDescription']

# %% [markdown]
# # Test Case-1 : Let us check if we created a Generator

# %%
cars
# Out:
# <generator object <genexpr> at 0x000001FEFE612A48>

# %%
def gen_car():
   for each_car in cars:
      yield each_car
car_gen = gen_car()
car_gen
# Out:
# <generator object gen_car at 0x000001FEFE612BC8>

# %% [markdown]
# # Test Case-2 : Let's read iteratively

# %%
for element in car_gen:
    print(element)
# Out:
# CarParking(SummonsNumber=4006478550, PlateID='VAD7274', RegistrationState='VA', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 5, 0, 0), ViolationCode=5, VehicleBodyType='4D', VehicleMake='BMW', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4006462396, PlateID='22834JK', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 9, 30, 0, 0), ViolationCode=5, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4007117810, PlateID='21791MG', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 10, 0, 0), ViolationCode=5, VehicleBodyType='VAN', VehicleMake='DODGE', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4006265037, PlateID='FZX9232', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 23, 0, 0), ViolationCode=5, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4006535600, PlateID='N203399C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 10, 19, 0, 0), ViolationCode=5, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4007156700, PlateID='92163MG', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 13, 0, 0), ViolationCode=5, VehicleBodyType='VAN', VehicleMake='FRUEH', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4006687989, PlateID='MIQ600', RegistrationState='SC', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 21, 0, 0), ViolationCode=5, VehicleBodyType='VN', VehicleMake='HONDA', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4006943052, PlateID='2AE3984', RegistrationState='MD', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 1, 0, 0), ViolationCode=5, VehicleBodyType='SW', VehicleMake='LINCO', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4007306795, PlateID='HLG4926', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 30, 0, 0), ViolationCode=5, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=4007124590, PlateID='T715907C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2017, 4, 3, 0, 0), ViolationCode=5, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='BUS LANE VIOLATION')
# CarParking(SummonsNumber=5096061966, PlateID='HRC9475', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 18, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='CADIL', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094070400, PlateID='DYP8042', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 26, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094906770, PlateID='G30ESY', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 1, 0, 0), ViolationCode=7, VehicleBodyType='WAGO', VehicleMake='CHRYS', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093319363, PlateID='GGT8868', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 6, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='CHRYS', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092638849, PlateID='107DDD', RegistrationState='NY', PlateType='SPO', IssueDate=datetime.datetime(2016, 7, 20, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='DODGE', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093455337, PlateID='ENQT55', RegistrationState='FL', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 12, 0, 0), ViolationCode=7, VehicleBodyType='VN', VehicleMake='DODGE', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094961366, PlateID='GSU4156', RegistrationState='OH', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 7, 0, 0), ViolationCode=7, VehicleBodyType='4S', VehicleMake='DODGE', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092906534, PlateID='V84FXV', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 7, 0, 0), ViolationCode=7, VehicleBodyType='WAGO', VehicleMake='FIR', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093620865, PlateID='AD80228', RegistrationState='AZ', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 24, 0, 0), ViolationCode=7, VehicleBodyType='TK', VehicleMake='FORD', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092733548, PlateID='EVX4041', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 26, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5095995530, PlateID='EMK5934', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 13, 0, 0), ViolationCode=7, VehicleBodyType='VAN', VehicleMake='GMC', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092750364, PlateID='DPH8955', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 27, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094658001, PlateID='GCF1897', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 10, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='HONDA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092833786, PlateID='HCS9434', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 3, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5096484040, PlateID='HHS1641', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 17, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5095797586, PlateID='KHE1889', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 28, 0, 0), ViolationCode=7, VehicleBodyType='SDN', VehicleMake='HONDA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5095799807, PlateID='VES2440', RegistrationState='VA', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 29, 0, 0), ViolationCode=7, VehicleBodyType='VAN', VehicleMake='HONDA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093533919, PlateID='CYU4598', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 16, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='HYUND', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093399735, PlateID='DZGT24', RegistrationState='FL', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 4, 0, 0), ViolationCode=7, VehicleBodyType='UT', VehicleMake='HYUND', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094058873, PlateID='GRN3101', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 29, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='HYUND', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094770986, PlateID='T668962C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 12, 19, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='HYUND', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093895611, PlateID='GVZ1407', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 14, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='JAGUA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094185792, PlateID='AGM9013', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 4, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='JEEP', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092708219, PlateID='F47DZF', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 24, 0, 0), ViolationCode=7, VehicleBodyType='4 DR', VehicleMake='JEEP', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094759954, PlateID='GLB8157', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 19, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='JEEP', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093891046, PlateID='FJS4033', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 14, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093527853, PlateID='GYM9809', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 21, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5096683886, PlateID='HCS4873', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 18, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5096917368, PlateID='FZD8593', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 13, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='ME/BE', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094893737, PlateID='GER1584', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 31, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='ME/BE', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5096249300, PlateID='HEM8411', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 1, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='ME/BE', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5096958772, PlateID='165TRX', RegistrationState='CT', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 16, 0, 0), ViolationCode=7, VehicleBodyType='4W', VehicleMake='MERCU', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093703217, PlateID='HFG4313', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 30, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='MITSU', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094670736, PlateID='AXU4790', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 11, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5094094166, PlateID='CZM4111', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 28, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5096723768, PlateID='EDN2797', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 2, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5093209120, PlateID='FZT5005', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 28, 0, 0), ViolationCode=7, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092469481, PlateID='GZH7067', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 10, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5092451658, PlateID='GZH7067', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 8, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=5095356545, PlateID='GZM8254', RegistrationState='NY', PlateType='OMS', IssueDate=datetime.datetime(2017, 2, 18, 0, 0), ViolationCode=7, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='FAILURE TO STOP AT RED LIGHT')
# CarParking(SummonsNumber=8410006650, PlateID='D53AUUN', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 21, 0, 0), ViolationCode=9, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='09-Blocking the Box')
# CarParking(SummonsNumber=8534116519, PlateID='CES6482', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 12, 0, 0), ViolationCode=9, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='09-Blocking the Box')
# CarParking(SummonsNumber=8485674984, PlateID='T713160C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2017, 6, 13, 0, 0), ViolationCode=9, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='09-Blocking the Box')
# CarParking(SummonsNumber=8556557405, PlateID='59622JW', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 9, 0, 0), ViolationCode=10, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='10-No Stopping')
# CarParking(SummonsNumber=8071038416, PlateID='AM479F', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 7, 0, 0), ViolationCode=10, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='10-No Stopping')
# CarParking(SummonsNumber=8483087236, PlateID='76822MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 5, 19, 0, 0), ViolationCode=10, VehicleBodyType='DELV', VehicleMake='HIN', ViolationDescription='10-No Stopping')
# CarParking(SummonsNumber=8481125088, PlateID='55179ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 10, 0, 0), ViolationCode=10, VehicleBodyType='DELV', VehicleMake='NS/OT', ViolationDescription='10-No Stopping')
# CarParking(SummonsNumber=8506822300, PlateID='55106MB', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 5, 31, 0, 0), ViolationCode=10, VehicleBodyType='VAN', VehicleMake='WORKH', ViolationDescription='10-No Stopping')
# CarParking(SummonsNumber=8482331425, PlateID='86609MB', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 18, 0, 0), ViolationCode=13, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='13-No Stand (taxi stand)')
# CarParking(SummonsNumber=8028246722, PlateID='T703619C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 9, 15, 0, 0), ViolationCode=13, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='13-No Stand (taxi stand)')
# CarParking(SummonsNumber=8378547530, PlateID='FWZ8815', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 11, 0, 0), ViolationCode=14, VehicleBodyType='2DSD', VehicleMake='ACURA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8489750210, PlateID='6DQT356', RegistrationState='CA', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 28, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='AUDI', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1410726095, PlateID='DEP4792', RegistrationState='NC', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 15, 0, 0), ViolationCode=14, VehicleBodyType='', VehicleMake='BMW', ViolationDescription='')
# CarParking(SummonsNumber=8421031235, PlateID='GGA4266', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 18, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='BMW', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7730553259, PlateID='DLZ8901', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 26, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8498520046, PlateID='HKF6916', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 27, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8537807813, PlateID='HNF6718', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 21, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8083571465, PlateID='KCG9559', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 22, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7536689184, PlateID='ZCL5723', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 26, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8480505680, PlateID='HCT2134', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 18, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='CHRYS', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8481973580, PlateID='28693MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 13, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8460500214, PlateID='30408MC', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 8, 4, 0, 0), ViolationCode=14, VehicleBodyType='PICK', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8482817036, PlateID='50501JT', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 11, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8117027999, PlateID='83317ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 9, 27, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8488121532, PlateID='FLX2674', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 5, 0, 0), ViolationCode=14, VehicleBodyType='2DSD', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8543952980, PlateID='FSZ8671', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 21, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8501806912, PlateID='KGP1166', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 4, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='DODGE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8107542976, PlateID='11AH74', RegistrationState='MA', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 29, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8564650320, PlateID='29222MK', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 5, 5, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8010367576, PlateID='30661MA', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 12, 22, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8505159536, PlateID='41795JX', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 3, 9, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7813887440, PlateID='44267JZ', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 8, 12, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8440509546, PlateID='49317JX', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 10, 29, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1408575656, PlateID='6XWZ969', RegistrationState='CA', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 6, 0, 0), ViolationCode=14, VehicleBodyType='SDN', VehicleMake='FORD', ViolationDescription='')
# CarParking(SummonsNumber=8516853275, PlateID='72100MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 12, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7059924103, PlateID='91878MB', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 10, 12, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8170085561, PlateID='ENM3708', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 10, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8527511113, PlateID='F70GEP', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 1, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8511453696, PlateID='FSY6987', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 13, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1413745933, PlateID='HCC2829', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 22, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='')
# CarParking(SummonsNumber=8484882226, PlateID='S25DSK', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 8, 0, 0), ViolationCode=14, VehicleBodyType='PICK', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8524054499, PlateID='ZRK24R', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 18, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1423945281, PlateID='2240653', RegistrationState='IN', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 13, 0, 0), ViolationCode=14, VehicleBodyType='', VehicleMake='FRUEH', ViolationDescription='')
# CarParking(SummonsNumber=8577650820, PlateID='10632JU', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 20, 0, 0), ViolationCode=14, VehicleBodyType='UTIL', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7056662882, PlateID='83038ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 9, 21, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8324025510, PlateID='83146ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 10, 27, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8286541110, PlateID='85846MD', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 10, 25, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8270548250, PlateID='91028MJ', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 12, 13, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8480520395, PlateID='99886MC', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 19, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8496410791, PlateID='AP338E', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 17, 0, 0), ViolationCode=14, VehicleBodyType='TRAC', VehicleMake='FRUEH', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8530950458, PlateID='HAY5880', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 8, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='GMC', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8552003569, PlateID='XJ275S', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 25, 0, 0), ViolationCode=14, VehicleBodyType='PICK', VehicleMake='GMC', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8536010903, PlateID='25472MG', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 16, 0, 0), ViolationCode=14, VehicleBodyType='REFG', VehicleMake='HIN', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8508953549, PlateID='XDLS80', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 1, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='HIN', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7191990831, PlateID='AA00234', RegistrationState='CT', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 2, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8519503676, PlateID='FCX7311', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 20, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1418739704, PlateID='GJK5307', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 9, 0, 0), ViolationCode=14, VehicleBodyType='SDN', VehicleMake='HONDA', ViolationDescription='')
# CarParking(SummonsNumber=7994359840, PlateID='GNG1097', RegistrationState='TX', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 15, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1414856374, PlateID='HLE9929', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 13, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='')
# CarParking(SummonsNumber=8474909971, PlateID='S938464', RegistrationState='IA', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 9, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1416903379, PlateID='CRM6911', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 16, 0, 0), ViolationCode=14, VehicleBodyType='SDN', VehicleMake='HYUND', ViolationDescription='')
# CarParking(SummonsNumber=8340512559, PlateID='CZB9676', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 23, 0, 0), ViolationCode=14, VehicleBodyType='2DSD', VehicleMake='HYUND', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8497566683, PlateID='17596JE', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 16, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8517821075, PlateID='32295MA', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 27, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1418035762, PlateID='62935JM', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 1, 24, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='')
# CarParking(SummonsNumber=8482055392, PlateID='92638JU', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 1, 25, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='INTER', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8506706490, PlateID='AP166T', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 20, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8473761297, PlateID='33049MJ', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 2, 1, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='ISUZU', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8484877693, PlateID='XBYG52', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 12, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='ISUZU', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8152046917, PlateID='VFW9441', RegistrationState='VA', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 14, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='JEEP', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8503265503, PlateID='23800TC', RegistrationState='NY', PlateType='TRC', IssueDate=datetime.datetime(2017, 3, 28, 0, 0), ViolationCode=14, VehicleBodyType='TRAC', VehicleMake='KENWO', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8489721312, PlateID='49734MA', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 4, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='KENWO', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8464532088, PlateID='HJR5750', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 3, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='KIA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8488825948, PlateID='HAU1278', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 31, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='LEXUS', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8559362496, PlateID='HLW7798', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 13, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8478353860, PlateID='VUE95C', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 6, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8518911631, PlateID='ZD53LE', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 17, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='LEXUS', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1416091415, PlateID='75213MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 11, 28, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='ME/BE', ViolationDescription='')
# CarParking(SummonsNumber=8482374059, PlateID='F96FBF', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 23, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='ME/BE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8544960947, PlateID='HMX8950', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 27, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='ME/BE', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1418609274, PlateID='8P82H', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 12, 21, 0, 0), ViolationCode=14, VehicleBodyType='TAXI', VehicleMake='NISSA', ViolationDescription='')
# CarParking(SummonsNumber=1417565895, PlateID='HEB8184', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 11, 0, 0), ViolationCode=14, VehicleBodyType='SDN', VehicleMake='NISSA', ViolationDescription='')
# CarParking(SummonsNumber=8155550278, PlateID='W56GSE', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 22, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7433187960, PlateID='2330830', RegistrationState='ME', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 6, 0, 0), ViolationCode=14, VehicleBodyType='TRLR', VehicleMake='NS/OT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7645052715, PlateID='FRZ3573', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 7, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='NS/OT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7922559173, PlateID='XCYU94', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 24, 0, 0), ViolationCode=14, VehicleBodyType='VAN', VehicleMake='NS/OT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7767415582, PlateID='XW915N', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 29, 0, 0), ViolationCode=14, VehicleBodyType='DELV', VehicleMake='NS/OT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8524350581, PlateID='HGR5953', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 27, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='OLDSM', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7499844705, PlateID='GGT7948', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 22, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='SUBAR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=7150327266, PlateID='HWE6388', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 5, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='SUBAR', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8537603818, PlateID='ASG8770', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 26, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8210533952, PlateID='GST8679', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 21, 0, 0), ViolationCode=14, VehicleBodyType='2DSD', VehicleMake='TOYOT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8555462198, PlateID='HKT4222', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 12, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=1404838156, PlateID='R57AAE', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 29, 0, 0), ViolationCode=14, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='')
# CarParking(SummonsNumber=8527806162, PlateID='T659832C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2017, 6, 4, 0, 0), ViolationCode=14, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8513520615, PlateID='77026MG', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 5, 31, 0, 0), ViolationCode=14, VehicleBodyType='TRAC', VehicleMake='VOLVO', ViolationDescription='14-No Standing')
# CarParking(SummonsNumber=8251031485, PlateID='HJP5565', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 4, 0, 0), ViolationCode=16, VehicleBodyType='4DSD', VehicleMake='CHEVR', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=7813745231, PlateID='GEL1890', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 19, 0, 0), ViolationCode=16, VehicleBodyType='SUBN', VehicleMake='CHRYS', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=8444534183, PlateID='36598MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 11, 23, 0, 0), ViolationCode=16, VehicleBodyType='VAN', VehicleMake='DODGE', ViolationDescription='16-No Std (Com Veh) Com Plate')
# CarParking(SummonsNumber=8061037749, PlateID='HFG7121', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 22, 0, 0), ViolationCode=16, VehicleBodyType='SUBN', VehicleMake='DODGE', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=8250539527, PlateID='24745ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 11, 9, 0, 0), ViolationCode=16, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='16-No Std (Com Veh) Com Plate')
# CarParking(SummonsNumber=8308520170, PlateID='49033ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 7, 14, 0, 0), ViolationCode=16, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='16-No Std (Com Veh) Com Plate')
# CarParking(SummonsNumber=8504915323, PlateID='57011ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 4, 6, 0, 0), ViolationCode=16, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='16-No Std (Com Veh) Com Plate')
# CarParking(SummonsNumber=8339536023, PlateID='XCEG93', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 15, 0, 0), ViolationCode=16, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='16-No Std (Com Veh) Com Plate')
# CarParking(SummonsNumber=8566405183, PlateID='GJD5585', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 1, 0, 0), ViolationCode=16, VehicleBodyType='4DSD', VehicleMake='ME/BE', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=7051225662, PlateID='N61GZN', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 25, 0, 0), ViolationCode=16, VehicleBodyType='SUBN', VehicleMake='SATUR', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=8149510126, PlateID='GTP8988', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 10, 0, 0), ViolationCode=16, VehicleBodyType='2DSD', VehicleMake='SMART', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=7052028463, PlateID='HGM9782', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 30, 0, 0), ViolationCode=16, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=8474913706, PlateID='T674455C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2017, 2, 8, 0, 0), ViolationCode=16, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='16A-No Std (Com Veh) Non-COM')
# CarParking(SummonsNumber=8506607206, PlateID='18752MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 3, 16, 0, 0), ViolationCode=17, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='17-No Stand (exc auth veh)')
# CarParking(SummonsNumber=8438519763, PlateID='89882JV', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 10, 13, 0, 0), ViolationCode=17, VehicleBodyType='VAN', VehicleMake='GMC', ViolationDescription='17-No Stand (exc auth veh)')
# CarParking(SummonsNumber=8551111954, PlateID='GCE9214', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 25, 0, 0), ViolationCode=17, VehicleBodyType='4DSD', VehicleMake='HONDA', ViolationDescription='17-No Stand (exc auth veh)')
# CarParking(SummonsNumber=8516654059, PlateID='AP169V', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 22, 0, 0), ViolationCode=18, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='18-No Stand (bus lane)')
# CarParking(SummonsNumber=1368119141, PlateID='BMLV150', RegistrationState='ON', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 16, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='')
# CarParking(SummonsNumber=8528274184, PlateID='EKF9820', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 1, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8522350073, PlateID='83290MD', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 2, 24, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='DODGE', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8070097437, PlateID='T62GJP', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 18, 0, 0), ViolationCode=19, VehicleBodyType='PICK', VehicleMake='DODGE', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8509409523, PlateID='35050JU', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 2, 24, 0, 0), ViolationCode=19, VehicleBodyType='PICK', VehicleMake='FORD', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1413553552, PlateID='41126BB', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 7, 28, 0, 0), ViolationCode=19, VehicleBodyType='VAN', VehicleMake='FORD', ViolationDescription='')
# CarParking(SummonsNumber=8514220482, PlateID='2588073', RegistrationState='IN', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 29, 0, 0), ViolationCode=19, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8485652319, PlateID='0480PRA', RegistrationState='MN', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 26, 0, 0), ViolationCode=19, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=7014671406, PlateID='B0951V', RegistrationState='FL', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 7, 0, 0), ViolationCode=19, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1422732710, PlateID='GMK4592', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 19, 0, 0), ViolationCode=19, VehicleBodyType='SDN', VehicleMake='HONDA', ViolationDescription='')
# CarParking(SummonsNumber=7249114220, PlateID='GPP7413', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 8, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=7499990163, PlateID='HKT3209', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 13, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8491667738, PlateID='JPC4516', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 1, 0, 0), ViolationCode=19, VehicleBodyType='4DSD', VehicleMake='INFIN', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8302046280, PlateID='63444JM', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 1, 26, 0, 0), ViolationCode=19, VehicleBodyType='VAN', VehicleMake='INTER', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8009901763, PlateID='13657MD', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 9, 27, 0, 0), ViolationCode=19, VehicleBodyType='DELV', VehicleMake='KENWO', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1424024420, PlateID='HPD1970', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 10, 0, 0), ViolationCode=19, VehicleBodyType='SDN', VehicleMake='KIA', ViolationDescription='')
# CarParking(SummonsNumber=8511718990, PlateID='50104MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 6, 9, 0, 0), ViolationCode=19, VehicleBodyType='VAN', VehicleMake='ME/BE', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1415429522, PlateID='17236MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 3, 3, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='MITSU', ViolationDescription='')
# CarParking(SummonsNumber=8476355312, PlateID='47829MD', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 2, 14, 0, 0), ViolationCode=19, VehicleBodyType='DELV', VehicleMake='PETER', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1406918726, PlateID='5M39B', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 7, 13, 0, 0), ViolationCode=19, VehicleBodyType='TAXI', VehicleMake='TOYOT', ViolationDescription='')
# CarParking(SummonsNumber=7241990262, PlateID='DVA1919', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 16, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8330511935, PlateID='HBY7509', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 30, 0, 0), ViolationCode=19, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1423536058, PlateID='HCS2336', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 27, 0, 0), ViolationCode=19, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='')
# CarParking(SummonsNumber=8519016595, PlateID='QU655', RegistrationState='RI', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 12, 0, 0), ViolationCode=19, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=8530522310, PlateID='T640396C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2017, 5, 27, 0, 0), ViolationCode=19, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='19-No Stand (bus stop)')
# CarParking(SummonsNumber=1413358512, PlateID='54295PC', RegistrationState='NY', PlateType='APP', IssueDate=datetime.datetime(2016, 8, 9, 0, 0), ViolationCode=19, VehicleBodyType='BUS', VehicleMake='', ViolationDescription='')
# CarParking(SummonsNumber=8269048434, PlateID='CDPE57', RegistrationState='FL', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 21, 0, 0), ViolationCode=20, VehicleBodyType='4DSD', VehicleMake='ACURA', ViolationDescription='20A-No Parking (Non-COM)')
# CarParking(SummonsNumber=7036998684, PlateID='VML8110', RegistrationState='VA', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 21, 0, 0), ViolationCode=20, VehicleBodyType='4DSD', VehicleMake='BMW', ViolationDescription='20A-No Parking (Non-COM)')
# CarParking(SummonsNumber=8515215408, PlateID='HFB1731', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 14, 0, 0), ViolationCode=20, VehicleBodyType='SUBN', VehicleMake='CADIL', ViolationDescription='20A-No Parking (Non-COM)')
# ...
# CarParking(SummonsNumber=8378044166, PlateID='HJV2326', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 18, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='INFIN', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8535421774, PlateID='EGZ5296', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 21, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='JEEP', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8263642668, PlateID='HEA6308', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 16, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='JEEP', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=7067047705, PlateID='HFF1432', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 23, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='JEEP', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8168032202, PlateID='GZN5776', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 3, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='LEXUS', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8507861787, PlateID='HMY3697', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 10, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='LEXUS', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8297047957, PlateID='GUV7315', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 12, 3, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='LINCO', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8472853342, PlateID='HJN6543', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 4, 0, 0), ViolationCode=71, VehicleBodyType='2DSD', VehicleMake='LINCO', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8524860388, PlateID='HGR2303', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 10, 0, 0), ViolationCode=71, VehicleBodyType='CONV', VehicleMake='ME/BE', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8561753377, PlateID='GWY8527', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 26, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='MERCU', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8544876754, PlateID='GBE4270', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 24, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=7803960030, PlateID='HBU4265', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 7, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=7492597289, PlateID='HDF5609', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 19, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8400523477, PlateID='HKT1200', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 28, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='71-Insp. Sticker Missing (NYS')
# CarParking(SummonsNumber=7646792536, PlateID='T686872C', RegistrationState='NY', PlateType='OMT', IssueDate=datetime.datetime(2016, 9, 14, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='NISSA', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8208026335, PlateID='DHW7141', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 5, 0, 0), ViolationCode=71, VehicleBodyType='2DSD', VehicleMake='NS/OT', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=7959796476, PlateID='GPY8489', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 6, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='ROVER', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8509455028, PlateID='34632BB', RegistrationState='NY', PlateType='OMR', IssueDate=datetime.datetime(2017, 2, 12, 0, 0), ViolationCode=71, VehicleBodyType='BUS', VehicleMake='STAR', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8393022400, PlateID='HFP5696', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 16, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='SUBAR', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8525217207, PlateID='HGM9849', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 3, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='SUBAR', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8562558047, PlateID='CWP4893', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 1, 0, 0), ViolationCode=71, VehicleBodyType='SUBN', VehicleMake='TOYOT', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8236037095, PlateID='GMR8112', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 17, 0, 0), ViolationCode=71, VehicleBodyType='2DSD', VehicleMake='TOYOT', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8514463690, PlateID='GMZ9712', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 30, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=8358550790, PlateID='HDY4158', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 18, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='TOYOT', ViolationDescription='71A-Insp Sticker Expired (NYS)')
# CarParking(SummonsNumber=7959486440, PlateID='GYF2052', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 7, 7, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='VOLKS', ViolationDescription='71-Insp. Sticker Missing (NYS')
# CarParking(SummonsNumber=8300538318, PlateID='HFR6545', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 31, 0, 0), ViolationCode=71, VehicleBodyType='4DSD', VehicleMake='VOLVO', ViolationDescription='71-Insp. Sticker Missing (NYS')
# CarParking(SummonsNumber=8523013120, PlateID='HPN9774', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 6, 0, 0), ViolationCode=74, VehicleBodyType='4DSD', VehicleMake='CHEVR', ViolationDescription='74-Missing Display Plate')
# CarParking(SummonsNumber=7008336767, PlateID='HWL4734', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 14, 0, 0), ViolationCode=74, VehicleBodyType='4DSD', VehicleMake='CHEVR', ViolationDescription='74A-Improperly Displayed Plate')
# CarParking(SummonsNumber=8397514636, PlateID='FYW3850', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 22, 0, 0), ViolationCode=74, VehicleBodyType='SUBN', VehicleMake='FORD', ViolationDescription='74A-Improperly Displayed Plate')
# CarParking(SummonsNumber=8528912840, PlateID='HNY5206', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 21, 0, 0), ViolationCode=74, VehicleBodyType='SUBN', VehicleMake='GMC', ViolationDescription='74A-Improperly Displayed Plate')
# CarParking(SummonsNumber=8511501113, PlateID='FBP6836', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 16, 0, 0), ViolationCode=74, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='74-Missing Display Plate')
# CarParking(SummonsNumber=8276551890, PlateID='HJR4081', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 1, 7, 0, 0), ViolationCode=74, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='74A-Improperly Displayed Plate')
# CarParking(SummonsNumber=8214550531, PlateID='HJY2207', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 9, 0, 0), ViolationCode=74, VehicleBodyType='4DSD', VehicleMake='HYUND', ViolationDescription='74-Missing Display Plate')
# CarParking(SummonsNumber=8487469012, PlateID='27527ME', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 1, 27, 0, 0), ViolationCode=74, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='74-Missing Display Plate')
# CarParking(SummonsNumber=8034780236, PlateID='HCD3158', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 2, 0, 0), ViolationCode=74, VehicleBodyType='SUBN', VehicleMake='KIA', ViolationDescription='74A-Improperly Displayed Plate')
# CarParking(SummonsNumber=8545052455, PlateID='HMK1149', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 7, 0, 0), ViolationCode=74, VehicleBodyType='4DSD', VehicleMake='ME/BE', ViolationDescription='74-Missing Display Plate')
# CarParking(SummonsNumber=1411263467, PlateID='BLANKPLATE', RegistrationState='99', PlateType='999', IssueDate=datetime.datetime(2017, 2, 13, 0, 0), ViolationCode=74, VehicleBodyType='SDN', VehicleMake='NISSA', ViolationDescription='')
# CarParking(SummonsNumber=8540001550, PlateID='HLA4803', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 23, 0, 0), ViolationCode=74, VehicleBodyType='4DSD', VehicleMake='SAAB', ViolationDescription='74-Missing Display Plate')
# CarParking(SummonsNumber=8556155431, PlateID='HFB9919', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 26, 0, 0), ViolationCode=75, VehicleBodyType='4DSD', VehicleMake='DODGE', ViolationDescription='75-No Match-Plate/Reg. Sticker')
# CarParking(SummonsNumber=8394016790, PlateID='31690BB', RegistrationState='NY', PlateType='OMR', IssueDate=datetime.datetime(2016, 9, 6, 0, 0), ViolationCode=77, VehicleBodyType='BUS', VehicleMake='AM/T', ViolationDescription='77-Parked Bus (exc desig area)')
# CarParking(SummonsNumber=1419472306, PlateID='56090BA', RegistrationState='NY', PlateType='OMR', IssueDate=datetime.datetime(2017, 2, 20, 0, 0), ViolationCode=77, VehicleBodyType='BUS', VehicleMake='INTER', ViolationDescription='')
# CarParking(SummonsNumber=8363508688, PlateID='97256', RegistrationState='MA', PlateType='APP', IssueDate=datetime.datetime(2016, 8, 13, 0, 0), ViolationCode=77, VehicleBodyType='BUS', VehicleMake='NS/OT', ViolationDescription='77-Parked Bus (exc desig area)')
# CarParking(SummonsNumber=1407740258, PlateID='2513JMG', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 1, 11, 0, 0), ViolationCode=78, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='')
# CarParking(SummonsNumber=8081047670, PlateID='AG84195', RegistrationState='AZ', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 1, 0, 0), ViolationCode=78, VehicleBodyType='DELV', VehicleMake='GMC', ViolationDescription='78-Nighttime PKG on Res Street')
# CarParking(SummonsNumber=8357010039, PlateID='ZBK5659', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 16, 0, 0), ViolationCode=78, VehicleBodyType='FLAT', VehicleMake='NS/OT', ViolationDescription='78-Nighttime PKG on Res Street')
# CarParking(SummonsNumber=1408164401, PlateID='GCP8663', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 9, 30, 0, 0), ViolationCode=80, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='')
# CarParking(SummonsNumber=7065087220, PlateID='35989MJ', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 8, 28, 0, 0), ViolationCode=82, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='82-Unaltered Commerc Vehicle')
# CarParking(SummonsNumber=8472028628, PlateID='80921MH', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2017, 1, 30, 0, 0), ViolationCode=82, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='82-Unaltered Commerc Vehicle')
# CarParking(SummonsNumber=8413507250, PlateID='XCGT11', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 10, 18, 0, 0), ViolationCode=82, VehicleBodyType='PICK', VehicleMake='CHEVR', ViolationDescription='82-Unaltered Commerc Vehicle')
# CarParking(SummonsNumber=8498413898, PlateID='2028133', RegistrationState='IN', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 24, 0, 0), ViolationCode=84, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=8484405837, PlateID='2028134', RegistrationState='IN', PlateType='PAS', IssueDate=datetime.datetime(2017, 2, 15, 0, 0), ViolationCode=84, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=8040125108, PlateID='AT985A', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 29, 0, 0), ViolationCode=84, VehicleBodyType='DELV', VehicleMake='FRUEH', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=8521821979, PlateID='XJX4470', RegistrationState='PA', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 18, 0, 0), ViolationCode=84, VehicleBodyType='TR/C', VehicleMake='FRUEH', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=7662741072, PlateID='XY237D', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 9, 0, 0), ViolationCode=84, VehicleBodyType='DELV', VehicleMake='HINO', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=8529157072, PlateID='2380604', RegistrationState='IN', PlateType='PAS', IssueDate=datetime.datetime(2017, 3, 29, 0, 0), ViolationCode=84, VehicleBodyType='DELV', VehicleMake='INTER', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=8354508808, PlateID='21239MG', RegistrationState='NY', PlateType='COM', IssueDate=datetime.datetime(2016, 9, 9, 0, 0), ViolationCode=84, VehicleBodyType='DELV', VehicleMake='MI/F', ViolationDescription='84-Platform lifts in low posit')
# CarParking(SummonsNumber=1414702700, PlateID='AT785J', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2016, 11, 27, 0, 0), ViolationCode=85, VehicleBodyType='TRAC', VehicleMake='FRUEH', ViolationDescription='')
# CarParking(SummonsNumber=8466533837, PlateID='XANK50', RegistrationState='NJ', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 29, 0, 0), ViolationCode=85, VehicleBodyType='DELV', VehicleMake='HIN', ViolationDescription='85-Storage-3 hour Commercial')
# CarParking(SummonsNumber=8525168063, PlateID='HBN8474', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 5, 30, 0, 0), ViolationCode=91, VehicleBodyType='SUBN', VehicleMake='HONDA', ViolationDescription='91-Veh for Sale (Dealer Only)')
# CarParking(SummonsNumber=1420730010, PlateID='GFW3620', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 6, 10, 0, 0), ViolationCode=98, VehicleBodyType='SUBN', VehicleMake='CHEVR', ViolationDescription='')
# CarParking(SummonsNumber=1414049870, PlateID='EJS4309', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2016, 8, 5, 0, 0), ViolationCode=98, VehicleBodyType='SDN', VehicleMake='NISSA', ViolationDescription='')
# CarParking(SummonsNumber=1420795430, PlateID='HBS5720', RegistrationState='NY', PlateType='PAS', IssueDate=datetime.datetime(2017, 4, 18, 0, 0), ViolationCode=98, VehicleBodyType='SDN', VehicleMake='NISSA', ViolationDescription='')

# %% [markdown]
# # Test Case-3- Generator should get exhausted

# %%
next(car_gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-12-31c21fc12cba> in <module>
# ----> 1 next(car_gen)
#
# StopIteration:

# %%
import collections, functools, operator

# %%
from collections import Counter

# %%
#goal2
def gen_car():
   for each_car in cars:
      yield each_car
car_gen = gen_car()
result_dict = collections.defaultdict(list)
for element in car_gen:
   result_dict[element.VehicleMake].append(element.ViolationCode)

violations_dict = {key:Counter(value_list) for key, value_list in result_dict.items()}

# %% [markdown]
# #  TestCase-4 : Count for each  Violation code field on car type

# %%
print(violations_dict)
# Out:
# {'BMW': Counter({36: 10, 21: 8, 37: 4, 38: 3, 40: 3, 14: 2, 5: 1, 20: 1, 70: 1, 71: 1}), 'CHEVR': Counter({21: 14, 36: 12, 38: 12, 14: 5, 71: 5, 46: 3, 82: 3, 13: 2, 19: 2, 20: 2, 37: 2, 40: 2, 74: 2, 5: 1, 7: 1, 16: 1, 17: 1, 24: 1, 31: 1, 42: 1, 69: 1, 80: 1, 98: 1}), 'DODGE': Counter({14: 7, 36: 7, 21: 4, 46: 4, 7: 3, 20: 3, 38: 3, 16: 2, 19: 2, 31: 2, 37: 2, 5: 1, 40: 1, 47: 1, 69: 1, 71: 1, 75: 1}), 'FORD': Counter({14: 15, 38: 15, 36: 13, 21: 12, 37: 7, 20: 5, 40: 5, 16: 4, 71: 4, 48: 3, 5: 2, 7: 2, 19: 2, 42: 2, 46: 2, 47: 2, 69: 2, 70: 2, 10: 1, 50: 1, 51: 1, 52: 1, 74: 1}), 'FRUEH': Counter({14: 8, 46: 8, 40: 4, 84: 4, 19: 3, 47: 3, 69: 3, 21: 2, 38: 2, 5: 1, 10: 1, 37: 1, 42: 1, 50: 1, 78: 1, 85: 1}), 'HONDA': Counter({21: 25, 36: 22, 38: 9, 20: 8, 7: 6, 14: 6, 37: 5, 40: 5, 46: 4, 71: 4, 19: 3, 48: 2, 50: 2, 74: 2, 5: 1, 17: 1, 91: 1}), 'LINCO': Counter({21: 3, 36: 3, 37: 3, 71: 2, 5: 1}), 'TOYOT': Counter({21: 27, 36: 15, 38: 15, 7: 6, 19: 6, 37: 6, 14: 5, 20: 5, 40: 5, 46: 5, 71: 4, 5: 2, 9: 2, 16: 2, 50: 2, 24: 1, 27: 1, 51: 1, 68: 1, 70: 1}), 'CADIL': Counter({20: 2, 38: 2, 7: 1, 24: 1, 31: 1, 36: 1, 70: 1}), 'CHRYS': Counter({7: 2, 21: 2, 14: 1, 16: 1, 20: 1, 36: 1, 37: 1, 38: 1, 70: 1, 71: 1}), 'FIR': Counter({7: 1}), 'GMC': Counter({38: 11, 21: 6, 36: 5, 14: 2, 37: 2, 40: 2, 7: 1, 17: 1, 20: 1, 47: 1, 69: 1, 74: 1, 78: 1}), 'HYUND': Counter({36: 8, 7: 4, 21: 4, 38: 4, 14: 2, 20: 2, 37: 2, 71: 2, 23: 1, 24: 1, 31: 1, 40: 1, 50: 1, 70: 1, 74: 1}), 'JAGUA': Counter({7: 1, 21: 1, 36: 1}), 'JEEP': Counter({7: 3, 24: 3, 71: 3, 20: 2, 21: 2, 36: 2, 38: 2, 14: 1, 37: 1, 40: 1, 46: 1, 70: 1}), 'LEXUS': Counter({36: 8, 14: 4, 7: 3, 21: 2, 38: 2, 71: 2, 9: 1, 31: 1, 37: 1, 46: 1, 53: 1}), 'ME/BE': Counter({21: 6, 36: 5, 38: 4, 7: 3, 14: 3, 20: 3, 37: 2, 40: 2, 70: 2, 16: 1, 19: 1, 31: 1, 46: 1, 47: 1, 53: 1, 71: 1, 74: 1}), 'MERCU': Counter({7: 1, 21: 1, 38: 1, 71: 1}), 'MITSU': Counter({46: 4, 40: 2, 47: 2, 7: 1, 19: 1, 36: 1}), 'NISSA': Counter({21: 16, 38: 11, 36: 10, 20: 5, 40: 5, 71: 5, 14: 3, 24: 2, 31: 2, 50: 2, 70: 2, 98: 2, 7: 1, 37: 1, 46: 1, 68: 1, 74: 1}), 'HIN': Counter({14: 2, 10: 1, 46: 1, 69: 1, 85: 1}), 'NS/OT': Counter({14: 4, 38: 3, 46: 3, 42: 2, 10: 1, 35: 1, 47: 1, 71: 1, 77: 1, 78: 1}), 'WORKH': Counter({10: 1, 40: 1}), 'ACURA': Counter({38: 4, 21: 2, 46: 2, 14: 1, 20: 1, 53: 1, 71: 1}), 'AUDI': Counter({21: 3, 24: 2, 38: 2, 14: 1, 36: 1, 37: 1, 46: 1, 70: 1}), 'INTER': Counter({14: 5, 47: 4, 40: 2, 69: 2, 18: 1, 19: 1, 21: 1, 36: 1, 37: 1, 38: 1, 48: 1, 50: 1, 64: 1, 74: 1, 77: 1, 84: 1}), 'ISUZU': Counter({14: 2, 46: 2, 47: 2, 26: 1, 38: 1, 50: 1, 69: 1}), 'KENWO': Counter({14: 2, 19: 1, 46: 1, 47: 1}), 'KIA': Counter({38: 2, 14: 1, 19: 1, 20: 1, 36: 1, 37: 1, 74: 1}), 'OLDSM': Counter({14: 1}), 'SUBAR': Counter({21: 6, 36: 3, 14: 2, 71: 2, 20: 1, 38: 1, 40: 1, 68: 1, 70: 1}), 'VOLVO': Counter({38: 3, 36: 2, 14: 1, 21: 1, 31: 1, 37: 1, 46: 1, 53: 1, 71: 1}), 'SATUR': Counter({16: 1, 53: 1}), 'SMART': Counter({16: 1, 21: 1, 36: 1}), 'INFIN': Counter({36: 3, 38: 3, 37: 2, 19: 1, 20: 1, 31: 1, 40: 1, 71: 1}), 'PETER': Counter({19: 1}), '': Counter({46: 3, 19: 1, 21: 1}), 'CITRO': Counter({20: 1}), 'ROVER': Counter({46: 2, 20: 1, 31: 1, 71: 1}), 'BUICK': Counter({21: 2, 36: 1, 40: 1, 46: 1}), 'GEO': Counter({21: 1}), 'MAZDA': Counter({21: 4, 37: 1}), 'PORSC': Counter({21: 1, 38: 1, 40: 1}), 'VOLKS': Counter({21: 3, 36: 2, 24: 1, 38: 1, 71: 1}), 'YAMAH': Counter({21: 1}), 'BSA': Counter({31: 1}), 'MINI': Counter({36: 1}), 'PONTI': Counter({37: 1}), 'SPRI': Counter({37: 1}), 'PLYMO': Counter({38: 1}), 'SCION': Counter({38: 1, 40: 1}), 'UPS': Counter({40: 1}), 'FIAT': Counter({46: 1}), 'UD': Counter({46: 1}), 'UTILI': Counter({46: 1}), 'GMCQ': Counter({48: 1}), 'SAAB': Counter({51: 1, 74: 1}), 'HINO': Counter({53: 1, 84: 1}), 'STAR': Counter({71: 1}), 'AM/T': Counter({77: 1}), 'MI/F': Counter({84: 1})}

# %% [markdown]
# #  TestCase-5 : Generator get exhausted

# %%
next(car_gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-21-31c21fc12cba> in <module>
# ----> 1 next(car_gen)
#
# StopIteration:

# %% [markdown]
# # Count of the Car violation based on Car name as input

# %%
def violation_car(car_make):
    for each_car in cars:
        if each_car.VehicleMake == car_make:
           yield each_car

# %% [markdown]
# # Test Case-6 : Count of Violation for BMW

# %%
print("The number of violation for the given car is", len(list(violation_car('BMW'))))
# Out:
# The number of violation for the given car is 0
